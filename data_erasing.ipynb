# %%
import os
import shutil

NAMA_FILE = "0001389_jpg.rf.10cd0f53150a92f307d0e4d4930ea775"

FILENAME_LABEL = f"{NAMA_FILE}.txt"
FILENAME_IMAGES = f"{NAMA_FILE}.jpg"

SOURCE_FOLDER_LABEL = "C:/Users/USER/Desktop/deteksi-ragam-buah-yolov11/__DATASET FOR TRAIN 3/apel/train/labels"
SOURCE_FOLDER_IMAGES = "C:/Users/USER/Desktop/deteksi-ragam-buah-yolov11/__DATASET FOR TRAIN 3/apel/train/images"

file_label_path = os.path.join(SOURCE_FOLDER_LABEL, FILENAME_LABEL)
file_images_path = os.path.join(SOURCE_FOLDER_IMAGES, FILENAME_IMAGES)

if(os.path.exists(file_label_path) or os.path.exists(file_images_path)):
  os.remove(file_label_path)
  print("[INFO] Berhasil menghapus label.")
  os.remove(file_images_path)
  print("[INFO] Berhasil menghapus gambar.")
else:
  if(not os.path.exists(file_label_path)):
    print("[ERROR] Label tidak ada")
  if(not os.path.exists(file_images_path)):
    print("[ERROR] Gambar tidak ada")
# Out:
# [INFO] Berhasil menghapus label.
# [INFO] Berhasil menghapus gambar.

# %%
import os
import shutil

NAMA_FILE = [
  "_MG_3017_21_jpg.rf.693a1f67cb3fbabe4d48e20875362672",
  "_MG_8080_04_jpg.rf.4265ca84eca97b89ba6c37dd19060b7c",
  "_MG_8080_07_jpg.rf.30145fcc76b668fbe2e151554f5f8398",
  "_MG_8903_02_jpg.rf.862d9c27882eaae09b1e67d27d811fe0",
  "_MG_8903_16_jpg.rf.0e3b7c5d07af07339b83a91c464ab865",
  "_MG_9000_04_jpg.rf.b971f6b638d984da57c1d846c634868f"
]

SOURCE_FOLDER_LABEL = "C:/Users/USER/Desktop/deteksi-ragam-buah-yolov11/__DATASET FOR TRAIN 3/apel/train/labels"
SOURCE_FOLDER_IMAGES = "C:/Users/USER/Desktop/deteksi-ragam-buah-yolov11/__DATASET FOR TRAIN 3/apel/train/images"

for file in NAMA_FILE:

  FILENAME_LABEL = f"{file}.txt"
  FILENAME_IMAGES = f"{file}.jpg"
  
  file_label_path = os.path.join(SOURCE_FOLDER_LABEL, FILENAME_LABEL)
  file_images_path = os.path.join(SOURCE_FOLDER_IMAGES, FILENAME_IMAGES)
  
  if(os.path.exists(file_label_path) or os.path.exists(file_images_path)):
    os.remove(file_label_path)
    print("[INFO] Berhasil menghapus label.")
    os.remove(file_images_path)
    print("[INFO] Berhasil menghapus gambar.")
  else:
    if(not os.path.exists(file_label_path)):
      print("[ERROR] Label tidak ada")
      break
    if(not os.path.exists(file_images_path)):
      print("[ERROR] Gambar tidak ada")
      break
