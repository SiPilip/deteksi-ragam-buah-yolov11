# %% [markdown]
# ##### _Kelompok 15 Comvis (Philifs, Julio, Ejik)_

# %% [markdown]
# ## Pengggabungan Nama Kelas
#
# Dikarenakan kita memiliki data gambar dari 10 kelas yang berbeda beda.
#
# Dibutuhkan fungsi untuk menggabungkan tiap dataset gambar dari 10 kelas, menjadi satu dataset utuh yang akan digunakan oleh model.

# %%
import os
import shutil

# Folder dataset
source_folders = [
    'dataset/apel/train/images/',
    'dataset/belimbing/train/images/',
    'dataset/belimbing2/train/images/',
    'dataset/ceri/train/images/',
    'dataset/kiwi/train/images/',
    'dataset/kiwi2/train/images/',
    'dataset/kurma/train/images/',
    'dataset/lemon/train/images/',
    'dataset/nanas/train/images/',
    'dataset/pisang/train/images/',
    'dataset/semangka/train/images/',
    'dataset/tomat/train/images/'
]

# Folder tujuan
output_folder = 'images/'
os.makedirs(output_folder, exist_ok=True)

totalDataTrain = 0

for folder in source_folders: # tiap folder dalam folder yang kita definisike
  for filename in os.listdir(folder): # tiap file dalam folderny
    source_path = os.path.join(folder, filename) # ex. dataset/apel/train/images
    destination_path = os.path.join(output_folder, filename) # ex. images/kiwi10330.jpg
    shutil.copy2(source_path, destination_path)
    totalDataTrain += 1

print(f'{totalDataTrain} gambar udah berhasil digabung! ✅')
# Out:
# 17566 gambar udah berhasil digabung! ✅
